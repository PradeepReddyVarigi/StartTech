# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Decision Tree

# %% [raw]
# Decision tree can be used both for classification and regression models
# Regression Trees (for continous quantitative target variable)E.g:Predicting revenue,rainfall,marks.
# classification (for discrete categorical varaiables) E.g:Prediciting High or low,Win or loss ,Healthy or unhealthy.

# %% [markdown]
# # Regression Tree

# %%
mov=pd.read_csv("C:/Users/prade/OneDrive/Desktop/DT RandomForestAdaboostXGboost/Movie_regression.csv",header=0)
mov.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views 3D_available  Time_taken  \
# ...

# %%
mov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Marketing expense    506 non-null    float64
#  1   Production expense   506 non-null    float64
#  2   Multiplex coverage   506 non-null    float64
#  3   Budget               506 non-null    float64
#  4   Movie_length         506 non-null    float64
#  5   Lead_ Actor_Rating   506 non-null    float64
#  6   Lead_Actress_rating  506 non-null    float64
#  7   Director_rating      506 non-null    float64
#  8   Producer_rating      506 non-null    float64
#  9   Critic_rating        506 non-null    float64
#  10  Trailer_views        506 non-null    int64
#  11  3D_available         506 non-null    object
#  12  Time_taken           494 non-null    float64
#  13  Twitter_hastags      506 non-null    float64
#  14  Genre                506 non-null    object
# ...

# %%
#Missing value treatment
mov['Time_taken'].mean()
# Out:
# 157.39149797570855

# %%
mov['Time_taken'].fillna(value=mov['Time_taken'].mean(),inplace=True)

# %%
mov.isnull().sum()
# Out:
# Marketing expense      0
# Production expense     0
# Multiplex coverage     0
# Budget                 0
# Movie_length           0
# Lead_ Actor_Rating     0
# Lead_Actress_rating    0
# Director_rating        0
# Producer_rating        0
# Critic_rating          0
# Trailer_views          0
# 3D_available           0
# Time_taken             0
# Twitter_hastags        0
# Genre                  0
# Avg_age_actors         0
# Num_multiplex          0
# Collection             0
# dtype: int64

# %%
#Dummy variable creation
mov.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views 3D_available  Time_taken  \
# ...

# %%
mov['Genre'].unique()
# Out:
# array(['Thriller', 'Drama', 'Comedy', 'Action'], dtype=object)

# %%
mov=pd.get_dummies(mov,columns=['3D_available','Genre'],drop_first=True)

# %%
mov.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views  Time_taken  Twitter_hastags  \
# ...

# %%
mov.columns
# Out:
# Index(['Marketing expense', 'Production expense', 'Multiplex coverage',
#        'Budget', 'Movie_length', 'Lead_ Actor_Rating', 'Lead_Actress_rating',
#        'Director_rating', 'Producer_rating', 'Critic_rating', 'Trailer_views',
#        'Time_taken', 'Twitter_hastags', 'Avg_age_actors', 'Num_multiplex',
#        'Collection', '3D_available_YES', 'Genre_Comedy', 'Genre_Drama',
#        'Genre_Thriller'],
#       dtype='object')

# %%
#splitting dependent and independent variable
x=mov.loc[:,mov.columns !='Collection']
y=mov['Collection']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,x_test,Y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
#Training Regression Tree
from sklearn import tree
regtree=tree.DecisionTreeRegressor(max_depth=3)

# %%
regtree.fit(X_train,Y_train)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
#predicting a model using trained model
y_train_pred=regtree.predict(X_train)
y_test_pred=regtree.predict(x_test)

# %%
y_train_pred[1:10]
# Out:
# array([46187.35632184, 65183.33333333, 46187.35632184, 23514.28571429,
#        35137.77777778, 46187.35632184, 46187.35632184, 65183.33333333,
#        23514.28571429])

# %%
y_test_pred[1:10]
# Out:
# array([100000.        ,  46187.35632184,  23514.28571429,  46187.35632184,
#         46187.35632184,  46187.35632184,  46187.35632184,  46187.35632184,
#         46187.35632184])

# %%
#Evaluating the performance of the model
from sklearn.metrics import mean_squared_error,r2_score
mean_squared_error(y_test,y_test_pred)
# Out:
# 139740942.91784033

# %%
r2_score(Y_train,y_train_pred)
# Out:
# 0.8364651040556869

# %%
r2_score(y_test,y_test_pred)
# Out:
# 0.5659203159203307

# %%
#Plotting Decision Tree
dot_data=tree.export_graphviz(regtree,out_file=None)

# %%
from IPython.display import Image

# %%
#!pip install pydotplus

# %%
#conda install python-graphviz

# %%
import os

os.environ['PATH'] = os.environ['PATH']+';'+os.environ['CONDA_PREFIX']+r"\Library\bin\graphviz"

# %%
import pydotplus

# %%
graph=pydotplus.graph_from_dot_data(dot_data)
Image(graph.create_png())

# %% [markdown]
# ###### Prunning tree Growth

# %%
#Maximum number of levels in tree
regtree1=tree.DecisionTreeRegressor(max_depth=3)
regtree1.fit(X_train,Y_train)
dot_data=tree.export_graphviz(regtree1,out_file=None,feature_names=X_train.columns,filled=True)
graph1=pydotplus.graph_from_dot_data(dot_data)
Image(graph1.create_png())

# %%
#Minimum observation i.e Samples required at internal node
regtree2=tree.DecisionTreeRegressor(min_samples_split=40)
regtree2.fit(X_train,Y_train)
dot_data=tree.export_graphviz(regtree2,out_file=None,feature_names=X_train.columns,filled=True)
graph2=pydotplus.graph_from_dot_data(dot_data)
Image(graph2.create_png())

# %%
#Minimum no of observation i.e samples on leafe node
regtree3=tree.DecisionTreeRegressor(min_samples_leaf=25)
regtree3.fit(X_train,Y_train)
dot_data=tree.export_graphviz(regtree3,out_file=None,feature_names=X_train.columns,filled=True)
graph3=pydotplus.graph_from_dot_data(dot_data)
Image(graph3.create_png())

# %%
regtree3=tree.DecisionTreeRegressor(min_samples_leaf=25,max_depth=4)
regtree3.fit(X_train,Y_train)
dot_data=tree.export_graphviz(regtree3,out_file=None,feature_names=X_train.columns,filled=True)
graph3=pydotplus.graph_from_dot_data(dot_data)
Image(graph3.create_png())

# %% [markdown]
# # Classification Tree

# %% [raw]
# As we can see,In Regression Tree we have predictied the collection of a movie where as in classification tree we are going to
# predict whether the movie award winning are no
# Note : In regression we used mean where as in classification we used mode
#
# In Regression trees we choose that split which give us minimum rss
# In classification we can't choose RSS we choose some thing like
# 1.Classification error rate : Which ever give us minimum classification error rate will keep that split
# 2.Gini Index
# 3.Cross entropy

# %%
movc=pd.read_csv("C:/Users/prade/OneDrive/Desktop/DT RandomForestAdaboostXGboost/Movie_classification.csv")

# %%
movc.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views 3D_available  Time_taken  \
# ...

# %%
movc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Marketing expense    506 non-null    float64
#  1   Production expense   506 non-null    float64
#  2   Multiplex coverage   506 non-null    float64
#  3   Budget               506 non-null    float64
#  4   Movie_length         506 non-null    float64
#  5   Lead_ Actor_Rating   506 non-null    float64
#  6   Lead_Actress_rating  506 non-null    float64
#  7   Director_rating      506 non-null    float64
#  8   Producer_rating      506 non-null    float64
#  9   Critic_rating        506 non-null    float64
#  10  Trailer_views        506 non-null    int64
#  11  3D_available         506 non-null    object
#  12  Time_taken           494 non-null    float64
#  13  Twitter_hastags      506 non-null    float64
#  14  Genre                506 non-null    object
# ...

# %%
movc.columns
# Out:
# Index(['Marketing expense', 'Production expense', 'Multiplex coverage',
#        'Budget', 'Movie_length', 'Lead_ Actor_Rating', 'Lead_Actress_rating',
#        'Director_rating', 'Producer_rating', 'Critic_rating', 'Trailer_views',
#        '3D_available', 'Time_taken', 'Twitter_hastags', 'Genre',
#        'Avg_age_actors', 'Num_multiplex', 'Collection', 'Start_Tech_Oscar'],
#       dtype='object')

# %%
movc['Time_taken'].mean()
# Out:
# 157.39149797570855

# %%
movc['Time_taken'].fillna(value=movc['Time_taken'].mean(),inplace=True)

# %%
movc.isnull().sum()
# Out:
# Marketing expense      0
# Production expense     0
# Multiplex coverage     0
# Budget                 0
# Movie_length           0
# Lead_ Actor_Rating     0
# Lead_Actress_rating    0
# Director_rating        0
# Producer_rating        0
# Critic_rating          0
# Trailer_views          0
# 3D_available           0
# Time_taken             0
# Twitter_hastags        0
# Genre                  0
# Avg_age_actors         0
# Num_multiplex          0
# Collection             0
# Start_Tech_Oscar       0
# dtype: int64

# %%
#Dummy varibles
movc.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views 3D_available  Time_taken  \
# ...

# %%
movc=pd.get_dummies(movc,columns=['3D_available','Genre'],drop_first=True)

# %%
movc.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  ...  Time_taken  Twitter_hastags  \
# ...

# %%
#Splitting the data
x=movc.loc[:,movc.columns!='Start_Tech_Oscar']
y=movc['Start_Tech_Oscar']

# %%
x.head(1)
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095             7.91
#
#    Producer_rating  Critic_rating  Trailer_views  Time_taken  Twitter_hastags  \
# 0            7.995           7.94         527367       109.6           223.84
#
#    Avg_age_actors  Num_multiplex  Collection  3D_available_YES  Genre_Comedy  \
# 0              23            494       48000                 1             0
#
#    Genre_Drama  Genre_Thriller
# 0            0               1

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    1
# Name: Start_Tech_Oscar, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_Train,x_Test,Y_Train,y_Test=train_test_split(x,y,test_size=0.2,random_state=0)

# %% [markdown]
# ###### Training and creating the classification Tree

# %%
from sklearn import tree

# %%
clftree=tree.DecisionTreeClassifier(max_depth=3)

# %%
clftree.fit(X_Train,Y_Train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
#Predicting values using trained model
Y_train_pred=clftree.predict(X_Train)
Y_Test_pred=clftree.predict(x_Test)

# %%
Y_train_pred[1:10]
# Out:
# array([0, 0, 0, 1, 1, 0, 0, 1, 0], dtype=int64)

# %%
Y_Test_pred[1:10]
# Out:
# array([1, 0, 1, 0, 0, 0, 0, 1, 0], dtype=int64)

# %% [markdown]
# ###### Model Performance

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
confusion_matrix(Y_Train,Y_train_pred)
# Out:
# array([[172,  14],
#        [126,  92]], dtype=int64)

# %%
confusion_matrix(y_Test,Y_Test_pred)
# Out:
# array([[39,  5],
#        [41, 17]], dtype=int64)

# %%
accuracy_score(y_Test,Y_Test_pred)
# Out:
# 0.5490196078431373

# %%
#plotting Decision Tree
dot_data=tree.export_graphviz(clftree,out_file=None,feature_names=X_Train.columns,filled=True)

# %%
from IPython.display import Image

# %%
import pydotplus

# %%
graph=pydotplus.graph_from_dot_data(dot_data)
Image(graph.create_png())

# %%
#Controlling Tree growth
clftree2=tree.DecisionTreeClassifier(min_samples_leaf=20,max_depth=4)
clftree2.fit(X_Train,Y_Train)
dot_data=tree.export_graphviz(clftree2,out_file=None,feature_names=X_Train.columns,filled=True)
graph2=pydotplus.graph_from_dot_data(dot_data)
Image(graph.create_png())

# %%
accuracy_score(y_Test,clftree2.predict(x_Test))
# Out:
# 0.5588235294117647

# %% [raw]
# Note:Problem with normal decision tree is having high variance

# %% [markdown]
# # Ensemble technique 1

# %% [markdown]
# ###### Bagging

# %%
from sklearn import tree
clftree=tree.DecisionTreeClassifier()

# %%
from sklearn.ensemble import BaggingClassifier

# %%
bag_clf=BaggingClassifier(base_estimator=clftree,n_estimators=1000,bootstrap=True,n_jobs=-1,random_state=42)

# %%
bag_clf.fit(X_Train,Y_Train)
# Out:
# BaggingClassifier(base_estimator=DecisionTreeClassifier(), n_estimators=1000,
#                   n_jobs=-1, random_state=42)

# %%
confusion_matrix(y_Test, bag_clf.predict(x_Test))
# Out:
# array([[27, 17],
#        [22, 36]], dtype=int64)

# %%
accuracy_score(y_Test,bag_clf.predict(x_Test))
# Out:
# 0.6176470588235294

# %% [markdown]
# # Ensemble technique 2

# %% [markdown]
# ###### Random Forests

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_clf=RandomForestClassifier(n_estimators=1000,n_jobs=1,random_state=42)

# %%
rf_clf.fit(X_Train,Y_Train)
# Out:
# RandomForestClassifier(n_estimators=1000, n_jobs=1, random_state=42)

# %%
confusion_matrix(y_Test,rf_clf.predict(x_Test))
# Out:
# array([[25, 19],
#        [18, 40]], dtype=int64)

# %%
accuracy_score(y_Test,rf_clf.predict(x_Test))
# Out:
# 0.6372549019607843

# %%
#Grid Search
from sklearn.model_selection import GridSearchCV

# %%
rf_clf=RandomForestClassifier(n_estimators=250,random_state=42)

# %%
params_grid={"max_features":[4,5,6,7,8,9,10],
            "min_samples_split":[2,3,10]}

# %%
grid_search=GridSearchCV(rf_clf,params_grid,n_jobs=1,cv=5,scoring='accuracy')

# %%
grid_search.fit(X_Train,Y_Train)
# Out:
# GridSearchCV(cv=5,
#              estimator=RandomForestClassifier(n_estimators=250,
#                                               random_state=42),
#              n_jobs=1,
#              param_grid={'max_features': [4, 5, 6, 7, 8, 9, 10],
#                          'min_samples_split': [2, 3, 10]},
#              scoring='accuracy')

# %%
grid_search.best_params_
# Out:
# {'max_features': 6, 'min_samples_split': 3}

# %%
cvrf_clf=grid_search.best_estimator_
cvrf_clf
# Out:
# RandomForestClassifier(max_features=6, min_samples_split=3, n_estimators=250,
#                        random_state=42)

# %%
accuracy_score(y_Test, cvrf_clf.predict(x_Test))
# Out:
# 0.6274509803921569

# %%
confusion_matrix(y_Test, cvrf_clf.predict(x_Test))
# Out:
# array([[25, 19],
#        [19, 39]], dtype=int64)

# %% [markdown]
# # Ensemble technique 3

# %% [markdown]
# ###### Boosting

# %% [raw]
# Boosting
# 1.Gradient Boost
# 2.Ada Boost
# 3.XG Boost

# %% [markdown]
# ###### Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc_clf=GradientBoostingClassifier()
gbc_clf.fit(X_Train,Y_Train)
# Out:
# GradientBoostingClassifier()

# %%
accuracy_score(y_Test,gbc_clf.predict(x_Test))
# Out:
# 0.5784313725490197

# %%
gbc_clf2=GradientBoostingClassifier(learning_rate=0.02,n_estimators=1000,max_depth=1)
gbc_clf2.fit(X_Train,Y_Train)
# Out:
# GradientBoostingClassifier(learning_rate=0.02, max_depth=1, n_estimators=1000)

# %%
accuracy_score(Y_Train,gbc_clf2.predict(X_Train))
# Out:
# 0.7623762376237624

# %%
accuracy_score(y_Test,gbc_clf2.predict(x_Test))
# Out:
# 0.6176470588235294

# %% [markdown]
# ###### Ada Boosting

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ada_clf = AdaBoostClassifier(learning_rate=0.02, n_estimators=5000)
ada_clf.fit(X_Train,Y_Train)
# Out:
# AdaBoostClassifier(learning_rate=0.02, n_estimators=5000)

# %%
accuracy_score(Y_Train,ada_clf.predict(X_Train))
# Out:
# 0.8886138613861386

# %%
accuracy_score(y_Test,ada_clf.predict(x_Test))
# Out:
# 0.6274509803921569

# %%
ada_clf2=AdaBoostClassifier(rf_clf,learning_rate=0.02,n_estimators=500)
ada_clf2
# Out:
# AdaBoostClassifier(base_estimator=RandomForestClassifier(n_estimators=250,
#                                                          random_state=42),
#                    learning_rate=0.02, n_estimators=500)

# %%
ada_clf2.fit(X_Train,Y_Train)
# Out:
# AdaBoostClassifier(base_estimator=RandomForestClassifier(n_estimators=250,
#                                                          random_state=42),
#                    learning_rate=0.02, n_estimators=500)

# %%
accuracy_score(y_Test,ada_clf2.predict(x_Test))
# Out:
# 0.6078431372549019

# %% [markdown]
# ###### XGBOOST

# %%
# !pip install xgboost

# %%
import xgboost as xgb

# %%
xgb_clf=xgb.XGBClassifier(max_depth=5,n_estimators=10000,learning_rate=0.3,n_jobs=-1)

# %%
xgb_clf.fit(X_Train,Y_Train)
# Out:
# C:\Users\prade\anaconda3\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [12:45:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
# ...

# %%
accuracy_score(y_Test,xgb_clf.predict(x_Test))
# Out:
# 0.6666666666666666

# %%
xgb.plot_importance(xgb_clf)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
xgb_clf=xgb.XGBClassifier(n_estimators=250,learning_rate=0.1,random_state=42)

# %%
param_test1={
    'max_depth':range(3,10,23),
    'gamma':[0.1,0.2,0.3],
    'subsample':[0.8,0.9],
    'colsample_bytree':[0.8,0.9],
    'reg_alpha':[1e-2,0.1,1]

}

# %%
grid_search=GridSearchCV(xgb_clf,param_test1,n_jobs=1,cv=5,scoring='accuracy')

# %%
grid_search.fit(X_Train,Y_Train)
# Out:
# C:\Users\prade\anaconda3\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [12:45:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
cvxg_clf=grid_search.best_estimator_
cvxg_clf
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.8, gamma=0.1, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=250, n_jobs=4, num_parallel_tree=1, random_state=42,
#               reg_alpha=0.1, reg_lambda=1, scale_pos_weight=1, subsample=0.8,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
accuracy_score(y_Test,cvxg_clf.predict(x_Test))
# Out:
# 0.6176470588235294

# %%
grid_search.best_params_
# Out:
# {'colsample_bytree': 0.8,
#  'gamma': 0.1,
#  'max_depth': 3,
#  'reg_alpha': 0.1,
#  'subsample': 0.8}

# %% [markdown]
# ###### Preprocessing and Preparing Data before making ML model

# %%
ho=pd.read_csv('C:/Users/prade/OneDrive/Desktop/DT RandomForestAdaboostXGboost/House_Price.csv')

# %%
ho.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
ho.shape
# Out:
# (506, 19)

# %% [raw]
# Univariate Anaiysis
# 1.Central Tendency
#     mean
#     median
#     mode
# 2.Dispersion
#     Range
#     Variance
#     Max & Min
#     IQR
#     Standard Deviation
# 3.Count/Null Count

# %%
ho.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    3.613524   41.136779    0.554695    6.284634   68.574901
# std      9.182176    8.601545    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006320   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.082045   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.256510   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    3.677083   48.100000    0.624000    6.623500   94.075000
# max     50.000000   88.976200   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %%
sns.jointplot(x='n_hot_rooms',y='price',data=ho);

# %%
sns.jointplot(x='rainfall',y='price',data=ho)

# %%
ho.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   498 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %%
#Analysing a cetogorical varible
sns.countplot(x='airport',data=ho)
# Out:
# <AxesSubplot:xlabel='airport', ylabel='count'>

# %%
sns.countplot(x='waterbody',data=ho)
# Out:
# <AxesSubplot:xlabel='waterbody', ylabel='count'>

# %%
sns.countplot(x='bus_ter',data=ho)
# Out:
# <AxesSubplot:xlabel='bus_ter', ylabel='count'>

# %% [markdown]
# ###### outlier Treatment

# %% [raw]
# Reasons may be
# 1.Data Entry Errors
# 2.Measurment Errors
# 3.Sample error ....etc
#
# Solution:
# Detecting outliers using EDD and visuliztion methods such as scatterplot, Histogram,or box plots
# Impute outliers

# %% [raw]
# # Observations
# 1.Missing values in n_hos_beds
# 2.skewness or outliers  in crime rate
# 3.Outliers in n_hot_rooms and rainfall
# 4.Bus_ter has only yes values

# %%
ho.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   498 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %%
 np.percentile(ho['n_hot_rooms'],[99])
# Out:
# array([15.39952])

# %%
 np.percentile(ho['n_hot_rooms'],[99])[0]
# Out:
# 15.39952

# %%
uv=np.percentile(ho['n_hot_rooms'],[99])[0]

# %%
ho[ho['n_hot_rooms']>uv]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 2     34.7     0.02729       37.07    0.4690     7.185  61.1   5.03   4.86
# 166   50.0     2.01019       49.58    0.6050     7.929  96.2   2.11   1.91
# 204   50.0     0.02009       32.68    0.4161     8.034  31.9   5.41   4.80
# 267   50.0     0.57834       33.97    0.5750     8.297  67.0   2.60   2.13
# 369   50.0     5.66998       48.10    0.6310     6.683  96.8   1.55   1.28
# 423   13.4     7.05042       48.10    0.6140     6.103  85.1   2.08   1.80
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 2     5.01   4.97      22.2       4.03      NO       7.394       101.12
# 166   2.31   1.86      25.3       3.70     YES       8.300        15.40
# 204   5.28   4.99      25.3       2.88     YES       8.900        15.40
# 267   2.43   2.52      27.0       7.44     YES       8.000        15.40
# 369   1.65   0.94      19.8       3.73     YES       6.700        15.40
# ...

# %%
ho['n_hot_rooms'][(ho['n_hot_rooms']>3*uv)]
# Out:
# 2      101.12
# 423     81.12
# Name: n_hot_rooms, dtype: float64

# %%
ho['n_hot_rooms'][(ho['n_hot_rooms']>3*uv)]==3*uv
# Out:
# 2      False
# 423    False
# Name: n_hot_rooms, dtype: bool

# %%
np.percentile(ho['rainfall'],[1])
# Out:
# array([20.])

# %%
np.percentile(ho['rainfall'],[1])[0]
# Out:
# 20.0

# %%
lv=np.percentile(ho['rainfall'],[1])[0]

# %%
ho[ho['rainfall']<lv]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 213   28.1     0.14052       40.59     0.489     6.375  32.3   4.11   3.92
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 213   4.18   3.57      21.4       9.38     YES       7.562      10.2248
#
#     waterbody  rainfall bus_ter     parks
# 213      None         3     YES  0.044019

# %%
ho['rainfall'][(ho['rainfall']<0.3*lv)]==0.3*lv
# Out:
# 213    False
# Name: rainfall, dtype: bool

# %%
sns.jointplot(x='crime_rate',y='price',data=ho)

# %%
ho.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    3.613524   41.136779    0.554695    6.284634   68.574901
# std      9.182176    8.601545    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006320   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.082045   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.256510   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    3.677083   48.100000    0.624000    6.623500   94.075000
# max     50.000000   88.976200   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %%
#Impute the missing values
ho['n_hos_beds']=ho['n_hos_beds'].fillna(ho['n_hos_beds'].mean())

# %%
ho.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   506 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %%
#Creating new column
ho['avg_dist']=(ho['dist1']+ho['dist1']+ho['dist2']+ho['dist3']+ho['dist4'])/4

# %%
ho.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks  avg_dist
# 0     River        23     YES  0.049347    5.1750
# ...

# %%
del ho['dist1']

# %%
del ho['dist2']

# %%
del ho['dist3']

# %%
del ho['dist4']

# %%
ho.columns
# Out:
# Index(['price', 'crime_rate', 'resid_area', 'air_qual', 'room_num', 'age',
#        'teachers', 'poor_prop', 'airport', 'n_hos_beds', 'n_hot_rooms',
#        'waterbody', 'rainfall', 'bus_ter', 'parks', 'avg_dist'],
#       dtype='object')

# %%
del ho['bus_ter']

# %%
#Dummy varible creation in python
ho=pd.get_dummies(ho)
ho.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2      24.7
# 1   21.6     0.02731       37.07     0.469     6.421  78.9      22.2
# 2   34.7     0.02729       37.07     0.469     7.185  61.1      22.2
# 3   33.4     0.03237       32.18     0.458     6.998  45.8      21.3
# 4   36.2     0.06905       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall     parks  avg_dist  \
# 0       4.98       5.480      11.1920        23  0.049347    5.1750
# 1       9.14       7.332      12.1728        42  0.046146    6.2150
# 2       4.03       7.394     101.1200        38  0.045764    6.2250
# 3       2.94       9.268      11.2672        45  0.047151    7.6175
# 4       5.33       8.824      11.2896        55  0.039474    7.6025
#
#    airport_NO  airport_YES  waterbody_Lake  waterbody_Lake and River  \
# ...

# %%
del ho['airport_NO']

# %%
del ho['waterbody_None']

# %%
ho.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2      24.7
# 1   21.6     0.02731       37.07     0.469     6.421  78.9      22.2
# 2   34.7     0.02729       37.07     0.469     7.185  61.1      22.2
# 3   33.4     0.03237       32.18     0.458     6.998  45.8      21.3
# 4   36.2     0.06905       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall     parks  avg_dist  \
# 0       4.98       5.480      11.1920        23  0.049347    5.1750
# 1       9.14       7.332      12.1728        42  0.046146    6.2150
# 2       4.03       7.394     101.1200        38  0.045764    6.2250
# 3       2.94       9.268      11.2672        45  0.047151    7.6175
# 4       5.33       8.824      11.2896        55  0.039474    7.6025
#
#    airport_YES  waterbody_Lake  waterbody_Lake and River  waterbody_River
# ...

# %%
ho.corr()
# Out:
#                              price  crime_rate  resid_area  air_qual  \
# price                     1.000000   -0.389582   -0.484754 -0.429300
# crime_rate               -0.389582    1.000000    0.406583  0.420972
# resid_area               -0.484754    0.406583    1.000000  0.763651
# air_qual                 -0.429300    0.420972    0.763651  1.000000
# room_num                  0.696304   -0.219247   -0.391676 -0.302188
# age                      -0.377999    0.352734    0.644779  0.731470
# teachers                  0.505655   -0.289946   -0.383248 -0.188933
# poor_prop                -0.740836    0.455621    0.603800  0.590879
# n_hos_beds                0.108880    0.017371    0.005799 -0.049553
# n_hot_rooms               0.023122    0.013518   -0.000839 -0.004882
# rainfall                 -0.047426    0.059204    0.055810  0.092104
# parks                    -0.391574    0.383235    0.707635  0.915544
# avg_dist                  0.249745   -0.379814   -0.707834 -0.769247
# ...
